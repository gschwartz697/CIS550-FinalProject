# %%
import json
import pandas as pd

with open("dataset/business.json") as business_file:
    business_df = pd.read_json(business_file, lines=True, encoding="latin1")
    
business_df
# Out:
#                                            address  \
# 0                                  691 Richmond Rd
# 1                                   2824 Milton Rd
# 2                              337 Danforth Avenue
# 3              7702 E Doubletree Ranch Rd, Ste 300
# 4                                   4719 N 20Th St
# 5                              2017 E Camelback Rd
# 6                          4425 N 24th St, Ste 125
# 7                                   5770 Butler St
# 8                               3220 Washington Rd
# 9                        1425 S Higley Rd, Ste 103
# 10                         11022 W Charleston Blvd
# 11                         9393 N 90th St, Ste 112
# 12                              9101 E Baseline Rd
# 13                                 12417 W Pima St
# 14                        9616 E Independence Blvd
# 15                                 190 E Dallas Rd
# 16                                        62 S Ctr
# ...

# %%
cols = ['address', 'business_id', 'city', 'name', 'categories', 'stars']
filter_business_df = business_df.filter(cols, axis=1)

filter_business_df['categories'] = filter_business_df['categories'].apply(lambda x: ",".join(map(str, x)))

filter_business_df
# Out:
#                                            address             business_id  \
# 0                                  691 Richmond Rd  YDf95gJZaq05wvo7hTQbbQ
# 1                                   2824 Milton Rd  mLwM-h2YhXl2NCgdS84_Bw
# 2                              337 Danforth Avenue  v2WhjAB3PIBA8J8VxG3wEg
# 3              7702 E Doubletree Ranch Rd, Ste 300  CVtCbSB1zUcUWg-9TNGTuQ
# 4                                   4719 N 20Th St  duHFBe87uNSXImQmvBh87Q
# 5                              2017 E Camelback Rd  uUEMrhJiL1a1pCA_I1SU7Q
# 6                          4425 N 24th St, Ste 125  2eJEUJIP54tex7T9YOcLSw
# 7                                   5770 Butler St  fEylCY3UEH8YJ0Xa7lu6lA
# 8                               3220 Washington Rd  kFtuYklkAIlmYw8RZAieGw
# 9                        1425 S Higley Rd, Ste 103  NqiQdFa93wzUJGo29NbTPQ
# 10                         11022 W Charleston Blvd  N9BN9ldVl1FNzcB9_eAstw
# ...

# %%
import numpy
numpy.set_printoptions(threshold=numpy.nan)

cities_df = filter_business_df.city.unique()
cities_df
# Out:
# array(['Richmond Heights', 'Charlotte', 'Toronto', 'Scottsdale', 'Phoenix',
#        'Pittsburgh', 'McMurray', 'Gilbert', 'Las Vegas', 'Mesa',
#        'Avondale', 'Matthews', 'Stanley', 'Cleveland', 'Pineville',
#        'Mississauga', 'Edinburgh', 'Montréal', 'Rocky River', 'Madison',
#        'Pickering', 'Richmond Hill', 'Middleton', 'Beachwood', 'Chandler',
#        'Ajax', 'North York', 'Parma Heights', 'Mc Kees Rocks', 'Champaign',
#        'Montreal', 'Tempe', 'Indian Trail', 'Stuttgart', 'Painesville',
#        'Urbana', 'Brecksville', 'Glasgow', 'Bedford', 'Glendale',
#        'Harrisburg', 'Cave Creek', 'Rosemere', 'Markham', 'Sun City',
#        'Verona', 'North Las Vegas', 'Northfield', 'Murrysville',
#        'Lakewood', 'Strongsville', 'Goodyear', 'Vaughan', 'Willoughby',
#        'Inverness', 'Gastonia', 'Wexford', 'Henderson', 'Peoria', 'Mentor',
#        'Huntersville', 'Whitby', 'North Olmsted', 'Elyria', 'Brossard',
# ...

# %%
filter_business_df.ix[119]

# %%
filter_business_df.ix[988]

# %%
locations_df = business_df.filter(['latitude', 'longitude'], axis=1)

locations_df

# %%
is_at_df = business_df.filter(['business_id', 'latitude', 'longitude'], axis = 1)

is_at_df

# %%
! pip install ipython-sql
! pip install pymysql
# %load_ext sql
try:
    import pymysql
    pymysql.install_as_MySQLdb()
except ImportError:
    pass
from sqlalchemy import create_engine
engine = create_engine('mysql://dorothychang:password450@cis450-final-project.ccgv1mp2bvqd.us-east-1.rds.amazonaws.com:3306/cis450finalproject?charset=utf8mb4', encoding='utf-8')

# is_at_df.to_sql(name='BusinessLocationRel', con=engine, if_exists='fail', index=False)
filter_business_df.to_sql(name='Business', con=engine, if_exists='replace', index=False)
# locations_df.to_sql(name='Locations', con=engine, if_exists='replace', index=False)

# %%
import tarfile
tar = tarfile.open("yelp_photos.tar")
tar.extractall()
tar.close()

# %%
# !pip install boto3

from __future__ import print_function
import boto3
import codecs
import json
import pandas as pd

dynamodb = boto3.resource('dynamodb', region_name='us-east-1', aws_access_key_id='AKIAJWIKNRMGP7MOBE4Q', aws_secret_access_key='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')
table = dynamodb.Table('cis450yelp-image-ids')

cols = ['business_id', 'city', 'name']
cities_df = business_df.filter(cols, axis=1)

with open("dataset/photos.json") as photos_file:
    photos_df = pd.read_json(photos_file, lines=True, encoding="latin1")
    
photos_df.set_index('business_id').join(cities_df.set_index('business_id'))
# Out:
# ...
#     100% |████████████████████████████████| 133kB 1.5MB/s ta 0:00:01
# ...
#     99% |████████████████████████████████| 4.0MB 2.6MB/s eta 0:00:011   11% |███▋                            | 460kB 2.9MB/s eta 0:00:02

# %%
! pip install ipython-sql
! pip install pymysql
# %load_ext sql
try:
    import pymysql
    pymysql.install_as_MySQLdb()
except ImportError:
    pass
from sqlalchemy import create_engine
engine = create_engine('mysql://dorothychang:password450@cis450-final-project.ccgv1mp2bvqd.us-east-1.rds.amazonaws.com:3306/cis450finalproject?charset=utf8mb4', encoding='utf-8')

#photos_df.to_sql(name='Business_Photos', con=engine, if_exists='replace', index=False)

photos_df
# Out:
# ...
#   Running setup.py bdist_wheel for prettytable ... done
#   Stored in directory: /home/jovyan/.cache/pip/wheels/b6/90/7b/1c22b89217d0eba6d5f406e562365ebee804f0d4595b2bdbcd
# Successfully built prettytable
# ...
#     100% |████████████████████████████████| 81kB 2.3MB/s ta 0:00:01
# ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-19a9b33e0b81> in <module>()
#      12 #photos_df.to_sql(name='Business_Photos', con=engine, if_exists='replace', index=False)
#      13
# ---> 14 photos_df
#
# NameError: name 'photos_df' is not defined

# %%
# !pip install boto3

from __future__ import print_function
import boto3
import codecs
import json
import pandas as pd

dynamodb = boto3.resource('dynamodb', region_name='us-east-1', aws_access_key_id='AKIAJWIKNRMGP7MOBE4Q', aws_secret_access_key='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')
table = dynamodb.Table('cis450-yelp-images')

with open("dataset/photos.json") as photos_file:
    photos = pd.read_json(photos_file, lines=True, encoding="latin1")
    
photos['business_id'].apply(lambda x: ",".join(map(str, x)))
    
for index, item in photos.iterrows():
    business_id = item['business_id']
    caption = item['caption']
    label = item['label']
    photo_id = item['photo_id']
    photo_url = "https://s3.amazonaws.com/450yelp-photos/" + photo_id + ".jpg"
    
    table.put_item(
        Item = {
            'business_id': business_id,
            'caption': caption,
            'label': label,
            'image_id': photo_id,
            'photo_url': photo_url,
        }
    )

# %%
import json
import pandas
import requests
from pandas.io.json import json_normalize

URL = "https://api.yelp.com/oauth2/token"

PARAMS = {
    'client_id': "ULvwtrZhKSP4iCjZWbluMg",
    'client_secret': "OKPc3bTTDcrW1Rbd90CdXpseVvozKM8Y4evQjZkjR3lUeDxVfkkXHKoJe1NAvz4d",
    'grant_type': "client_credentials",
}

data = requests.post(URL, params=PARAMS)
ACCESS_TOKEN = data.json()['access_token']

URL_G = "https://api.yelp.com/v3/businesses/search"

PARAMS_G = {
    'location': 'New York',
    'sort':0,
    'limit': 50,
    'offset': 50
}

headers = {
    'Authorization': 'Bearer %s' % ACCESS_TOKEN,
}

data_yelp = requests.get(URL_G, headers = headers, params = PARAMS_G)

data_yelp = data_yelp.json()

result = json_normalize(data_yelp, ['businesses'])


#result['categories'] = result['categories'].apply(lambda x: ",".join(map(str, x)))


#result['categories'] = result['categories'].apply(lambda x: ",".join(map(str, x)))
#cols = ['coordinates', 'categories', 'id', 'image_url', 'location', 'rating']
#result = result.filter(cols, axis=1)

result
# Out:
#                                            categories  \
# 0              [{'alias': 'parks', 'title': 'Parks'}]
# 1              [{'alias': 'parks', 'title': 'Parks'}]
# 2      [{'alias': 'coffee', 'title': 'Coffee & Tea'}]
# 3              [{'alias': 'pizza', 'title': 'Pizza'}]
# 4   [{'alias': 'landmarks', 'title': 'Landmarks & ...
# 5   [{'alias': 'coffee', 'title': 'Coffee & Tea'},...
# 6   [{'alias': 'mexican', 'title': 'Mexican'}, {'a...
# 7   [{'alias': 'bakeries', 'title': 'Bakeries'}, {...
# 8   [{'alias': 'wine_bars', 'title': 'Wine Bars'},...
# 9   [{'alias': 'mideastern', 'title': 'Middle East...
# 10  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...
# 11  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...
# 12           [{'alias': 'french', 'title': 'French'}]
# 13  [{'alias': 'modern_european', 'title': 'Modern...
# 14     [{'alias': 'coffee', 'title': 'Coffee & Tea'}]
# 15           [{'alias': 'indpak', 'title': 'Indian'}]
# ...

# %%
result['latitude']= result.apply(lambda row: row['coordinates']['latitude'], axis=1)
result['longitude']= result.apply(lambda row: row['coordinates']['longitude'], axis=1)
result['address']= result.apply(lambda row: ' '.join(row['location']['display_address']), axis=1)
result['categories']= result.apply(lambda row: str(row['categories']), axis=1)

# %%
cols = ['latitude', 'longitude', 'id', 'image_url', 'address', 'rating', 'url', 'name', 'price']
result = result.filter(cols, axis=1)

result
# Out:
#      latitude  longitude                                           id  \
# 0   40.701626 -73.997211              brooklyn-bridge-park-brooklyn-3
# 1   40.697931 -73.997136          brooklyn-heights-promenade-brooklyn
# 2   40.726990 -73.989220             coffee-project-new-york-new-york
# 3   40.711620 -73.957830                l-industrie-pizzeria-brooklyn
# 4   40.705968 -73.996666                     brooklyn-bridge-brooklyn
# 5   40.704884 -74.008977  periscope-coffee-on-pearl-street-new-york-4
# 6   40.718730 -73.986910                         la-contenta-new-york
# 7   40.707523 -73.950379                   mountain-province-brooklyn
# 8   40.726400 -73.984110    ruffian-wine-bar-and-chefs-table-new-york
# 9   40.717248 -73.944851                         pita-palace-brooklyn
# 10  40.742070 -74.005650                        los-mariscos-new-york
# 11  40.726860 -73.990750                       miscelanea-ny-new-york
# ...

# %%
locations__new_df = result.filter(['latitude', 'longitude'], axis=1)
is_df = result.filter(['id', 'latitude', 'longitude'], axis = 1)

# %%
! pip install ipython-sql
! pip install pymysql
# %load_ext sql
try:
    import pymysql
    pymysql.install_as_MySQLdb()
except ImportError:
    pass
from sqlalchemy import create_engine
engine = create_engine('mysql://dorothychang:password450@cis450-final-project.ccgv1mp2bvqd.us-east-1.rds.amazonaws.com:3306/cis450finalproject?charset=utf8mb4', encoding='utf-8')

is_df.to_sql(name='BusinessLocationRel', con=engine, if_exists='replace', index=False)
#filter_business_df.to_sql(name='Business', con=engine, if_exists='replace', index=False)
locations__new_df.to_sql(name='Locations', con=engine, if_exists='replace', index=False)
# Out:
# ...
#   Running setup.py bdist_wheel for prettytable ... done
#   Stored in directory: /home/jovyan/.cache/pip/wheels/b6/90/7b/1c22b89217d0eba6d5f406e562365ebee804f0d4595b2bdbcd
# Successfully built prettytable
# ...
#     100% |████████████████████████████████| 81kB 2.0MB/s ta 0:00:01
# ...
