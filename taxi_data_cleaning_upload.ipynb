# %%
import csv
import pandas as pd

host="cis450-final-project.ccgv1mp2bvqd.us-east-1.rds.amazonaws.com"
port=3306
dbname="cis450finalproject"
user="dorothychang"
password="password450"
conn = pymysql.connect(host, user=user,port=port, passwd=password, db=dbname)



with open('data.csv') as taxi_file:
    df = pd.read_csv(taxi_file, ',', nrows=1000000)

# %%
df
# Out:
#         VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0              2  2015-06-02 11:19:29   2015-06-02 11:47:52                1
# 1              2  2015-06-02 11:19:30   2015-06-02 11:27:56                1
# 2              2  2015-06-02 11:19:31   2015-06-02 11:30:30                1
# 3              2  2015-06-02 11:19:31   2015-06-02 11:39:02                1
# 4              1  2015-06-02 11:19:32   2015-06-02 11:32:49                1
# 5              1  2015-06-02 11:19:33   2015-06-02 11:28:48                1
# 6              1  2015-06-02 11:19:34   2015-06-02 11:38:46                1
# 7              1  2015-06-02 11:19:35   2015-06-02 12:36:46                4
# 8              2  2015-06-02 11:19:36   2015-06-02 11:45:19                1
# 9              1  2015-06-02 11:19:38   2015-06-02 11:23:50                1
# 10             2  2015-06-02 11:19:38   2015-06-02 11:19:43                3
# ...

# %%
def fillna_col (series):
    if series.dtype is pd.np.dtype(object):
        return series.fillna('') 
    else:
        return series

# %%
def nullify (param):
    if param == r'\N':
        return float('NaN')
    else: 
        return param

# %%
df = df.applymap(nullify)
df = df.apply(fillna_col)

# %%
df
# Out:
#         VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0              2  2015-06-02 11:19:29   2015-06-02 11:47:52                1
# 1              2  2015-06-02 11:19:30   2015-06-02 11:27:56                1
# 2              2  2015-06-02 11:19:31   2015-06-02 11:30:30                1
# 3              2  2015-06-02 11:19:31   2015-06-02 11:39:02                1
# 4              1  2015-06-02 11:19:32   2015-06-02 11:32:49                1
# 5              1  2015-06-02 11:19:33   2015-06-02 11:28:48                1
# 6              1  2015-06-02 11:19:34   2015-06-02 11:38:46                1
# 7              1  2015-06-02 11:19:35   2015-06-02 12:36:46                4
# 8              2  2015-06-02 11:19:36   2015-06-02 11:45:19                1
# 9              1  2015-06-02 11:19:38   2015-06-02 11:23:50                1
# 10             2  2015-06-02 11:19:38   2015-06-02 11:19:43                3
# ...

# %%
df.dtypes
# Out:
# VendorID                   int64
# tpep_pickup_datetime      object
# tpep_dropoff_datetime     object
# passenger_count            int64
# trip_distance            float64
# pickup_longitude         float64
# pickup_latitude          float64
# RateCodeID                 int64
# store_and_fwd_flag        object
# dropoff_longitude        float64
# dropoff_latitude         float64
# payment_type               int64
# fare_amount              float64
# extra                    float64
# mta_tax                  float64
# tip_amount               float64
# tolls_amount             float64
# improvement_surcharge    float64
# total_amount             float64
# dtype: object

# %%
df2 = df[['dropoff_latitude', 'dropoff_longitude']]
df2 = df2.rename(columns={'dropoff_longitude': 'longitude', 'dropoff_latitude':'latitude'})
df2 = df2.round({'longitude': 5, 'latitude': 5})
df2 = df2.groupby(['latitude', 'longitude']).size().reset_index(name='count')
df2 = df2.iloc[18:].reset_index()
df2 = df2.drop('index',axis=1)
df2 = df2.iloc[:930641]
df2
# Out:
#         latitude  longitude  count
# 0       40.30000  -73.95443      1
# 1       40.32324  -74.64435      1
# 2       40.34241  -74.55817      1
# 3       40.34242  -74.55819      1
# 4       40.34782  -74.49882      1
# 5       40.37313  -74.01233      1
# 6       40.38572  -74.12820      1
# 7       40.41943  -74.20864      1
# 8       40.44928  -74.29159      1
# 9       40.45419  -74.44199      1
# 10      40.47281  -74.27814      1
# 11      40.47569  -74.47749      1
# 12      40.47972  -74.40857      1
# 13      40.48455  -74.28011      1
# 14      40.49416  -74.51378      1
# 15      40.49747  -74.38799      1
# 16      40.50105  -74.23936      1
# 17      40.50330  -73.74014      1
# 18      40.51369  -74.23762      1
# 19      40.51740  -74.23304      1
# 20      40.51947  -74.33993      2
# 21      40.51953  -74.33981      1
# 22      40.51955  -74.33978      1
# 23      40.52056  -74.20828      1
# 24      40.52443  -74.20124      1
# 25      40.52593  -74.36190      1
# ...

# %%
df1 = df[['pickup_latitude', 'pickup_longitude']]
df1 = df1.rename(columns={'pickup_longitude': 'longitude', 'pickup_latitude':'latitude'})
df1 = df1.round({'longitude': 5, 'latitude': 5})
df1 = df1.groupby(['latitude', 'longitude']).size().reset_index(name='count')
df1 = df1.iloc[14:].reset_index()
df1 = df1.drop('index',axis=1)
df1 = df1.iloc[:886602]
df1
# Out:
#         latitude  longitude  count
# 0       40.12906  -68.61739      1
# 1       40.34242  -74.55818      1
# 2       40.44928  -74.29159      1
# 3       40.48454  -74.28011      1
# 4       40.49416  -74.51378      1
# 5       40.49746  -74.38799      1
# 6       40.51083  -73.73159      1
# 7       40.51947  -74.33993      1
# 8       40.51949  -74.33980      1
# 9       40.53204  -74.15910      1
# 10      40.53445  -74.16599      1
# 11      40.53903  -74.20935      1
# 12      40.53905  -74.20936      1
# 13      40.54853  -74.28982      1
# 14      40.55696  -74.26571      1
# 15      40.55904  -74.19788      1
# 16      40.56310  -74.32516      1
# 17      40.56336  -74.18191      1
# 18      40.57442  -73.98790      1
# 19      40.57710  -74.28731      1
# 20      40.57792  -73.96154      1
# 21      40.57903  -73.97617      1
# 22      40.57932  -73.98184      1
# 23      40.57976  -73.97795      1
# 24      40.57986  -73.94324      1
# 25      40.58120  -74.16758      1
# ...

# %%
! pip install ipython-sql
! pip install pymysql
# %load_ext sql
try:
    import pymysql
    pymysql.install_as_MySQLdb()
except ImportError:
    pass
from sqlalchemy import create_engine
engine = create_engine('mysql://dorothychang:password450@cis450-final-project.ccgv1mp2bvqd.us-east-1.rds.amazonaws.com:3306/cis450finalproject')
df1.to_sql(name='Taxi_Pickup', con=engine, if_exists='fail', index=False)
df2.to_sql(name='Taxi_Dropoff', con=engine, if_exists='fail', index=False)
# Out:
# ...
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
